# %% [markdown]
# <br>
# <center><img src="https://i.imgur.com/hkb7Bq7.png" width="500"></center>
#
#
# ### Prof. José Manuel Magallanes, PhD
#
# * Visiting Professor, Evans School of Public Policy and Governance / Senior Data Science Fellow, eScience Institute, University of Washington, [magajm@uw.edu](mailto:magajm@uw.edu)
#
# * Associate Professor, Departamento de Ciencias Sociales, Pontificia Universidad Católica del Perú, [jmagallanes@pucp.edu.pe](mailto:jmagallanes@pucp.edu.pe)
#
# _____
#
# _____

# %% [markdown]
# <a id='home'></a>
#
# # Introduction to Python
#
# * DATA STRUCTURES
#     - [Basic Data Structures](#basic_ds).
#
#     - [Complex Data Structures](#complex_ds).
#
# * DATA PRE PROCESSING
#     - [Data cleaning and formatting](#cleanformat).
#
#     - [Integration and Saving](#integratesave).

# %% [markdown]
# # Basic Data Structures

# %% [markdown]
# Python has basic native structures, like lists, tuples and dictionaries.

# %% [markdown]
# ## a.  **LISTS**
#
# Lists are the most flexible structure to save or contain data elements.

# %%
names=["Qing", "Françoise", "Raúl", "Bjork","Marie"]
ages=[32,33,28,30,29]
country=["China", "Senegal", "España", "Norway","Korea"]
education=["Bach", "Bach", "Master", "PhD","PhD"]

# %% [markdown]
# Above we have created some lists. Lists can contain any values. Lists support different operations:

# %% [markdown]
# * **Accessing**:
#
# Keep in mind the positions in Python start in **0**.

# %%
# one element
ages[0]
# Out:
# 32

# %%
# several, using slices:
ages[1:-1] #second to before last
# Out:
# [33, 28, 30]

# %%
# several, using slices:
ages[:-2] #all but two last ones
# Out:
# [32, 33, 28]

# %%
# non consecutive
from operator import itemgetter
list(itemgetter(0,2,3)(ages))
# Out:
# [32, 28, 30]

# %%
# difficul to understand?
ages[0:4:2] + [ages[3]]
# Out:
# [32, 28, 30]

# %% [markdown]
# * **Modifying**:

# %%
# by position
country[2]="Spain"

# list changed:
country
# Out:
# ['China', 'Senegal', 'Spain', 'Norway', 'Korea']

# %%
# by value
country=["PR China" if x == "China" else x for x in country]

# list changed:
country
# Out:
# ['PR China', 'Senegal', 'Spain', 'Norway', 'Korea']

# %% [markdown]
# * **Deleting**

# %%
# by position
del country[-1] #last value

# list changed:
country
# Out:
# ['PR China', 'Senegal', 'Spain', 'Norway']

# %%
# by position
names.pop() #last value by default

# list changed:
names
# Out:
# ['Qing', 'Françoise', 'Raúl', 'Bjork']

# %%
# only 'del' works for several positions

lista=[1,2,3,4,5,6]
del lista[1:3]

#now:
lista
# Out:
# [1, 4, 5, 6]

# %%
# by value
ages.remove(29) 

# list changed:
ages # just first ocurrence of value!!
# Out:
# [32, 33, 28, 30]

# %%
# by value
education.remove('PhD') 

# list changed:
education # just first ocurrence!!
# Out:
# ['Bach', 'Bach', 'Master', 'PhD']

# %%
# deleting every  value:

lista=[1,'a',45,'b','a']
lista=[x for x in lista if x!='a']

# you get:
lista
# Out:
# [1, 45, 'b']

# %% [markdown]
# * **Inserting values**

# %%
# at the end
lista.append("abc")
lista
# Out:
# [1, 45, 'b', 'abc']

# %%
# PART ONE:
# first delete a position
education.pop(2)
education
# Out:
# ['Bach', 'Bach', 'PhD']

# %%
# PART TWO:
# now insert in that position
education.insert(2,"Master")
education
# Out:
# ['Bach', 'Bach', 'Master', 'PhD']

# %% [markdown]
# ## b.  **TUPLES**
#
# Tuples are inmutable structures in Python, they look like lists but do not share much of their functionality:

# %%
# new list:
weekend=("Friday", "Saturday", "Sunday")

# %% [markdown]
# You can access:

# %%
weekend[0]
# Out:
# 'Friday'

# %% [markdown]
# But no other operation is allowed.

# %% [markdown]
# Python itself uses tuples as output of some important functions:

# %%
zip(names,ages)

# %% [markdown]
# The **zip** functions creates tuples, by combining in parallel. You can see it if you turn the result into a list:

# %%
list(zip(names,ages))  # a list of tuples
# Out:
# [('Qing', 32), ('Françoise', 33), ('Raúl', 28), ('Bjork', 30)]

# %% [markdown]
# [home](#home)
#
# ______
#
#
# <a id='complex_ds'></a>
#
# # Complex Data Structures
#
# ## a. **DICTIONARIES**
#
# *Dicts* work in a more sophisticated way, as they have a **'key'**:**'value'** structure:

# %%
classroom={'student':names,'age':ages,'edu':education}
# see it:

classroom
# Out:
# {'student': ['Qing', 'Françoise', 'Raúl', 'Bjork'],
#  'age': [32, 33, 28, 30],
#  'edu': ['Bach', 'Bach', 'Master', 'PhD']}

# %% [markdown]
# Dicts do not use indexes to access values:

# %%
#classroom[0]

# %% [markdown]
# Dicts use keys:

# %%
classroom['student']
# Out:
# ['Qing', 'Françoise', 'Raúl', 'Bjork']

# %% [markdown]
# Notice I created a dictionary where the value is not ONE but a LIST of values.

# %% [markdown]
# Once you access a value, you can modify it. You can also use _pop_ or _del_ using the **keys**. But you can not use _append_ to add an element, you need **update**:

# %%
classroom.update({'country':country})
# now:
classroom
# Out:
# {'student': ['Qing', 'Françoise', 'Raúl', 'Bjork'],
#  'age': [32, 33, 28, 30],
#  'edu': ['Bach', 'Bach', 'Master', 'PhD'],
#  'country': ['PR China', 'Senegal', 'Spain', 'Norway']}

# %% [markdown]
# ## b. DATA FRAMES

# %% [markdown]
# **Data frames**  are more complex containers of values. The most common analogy is a spreadsheet. To create a data frame, we need to call **pandas**:

# %%
import pandas

# %% [markdown]
# We can prepare a data frame from a dictionary immediately, but ONLY if you have the same amount of elements in each list representing a column.

# %%
# our data frame:
students=pandas.DataFrame(classroom)
## see it:
students
# Out:
#      student  age     edu   country
# 0       Qing   32    Bach  PR China
# 1  Françoise   33    Bach   Senegal
# 2       Raúl   28  Master     Spain
# 3      Bjork   30     PhD    Norway

# %% [markdown]
# But, let me update the dictionary with:

# %%
names=["Qing", "Françoise", "Raúl", "Bjork","Marie"]
#
classroom.update({'student':names})
#
classroom
# Out:
# {'student': ['Qing', 'Françoise', 'Raúl', 'Bjork', 'Marie'],
#  'age': [32, 33, 28, 30],
#  'edu': ['Bach', 'Bach', 'Master', 'PhD'],
#  'country': ['PR China', 'Senegal', 'Spain', 'Norway']}

# %% [markdown]
# We have five students, but only data for four of them. Then this does not work:

# %%
#pandas.DataFrame(classroom)

# %% [markdown]
# In that case, you need this:

# %%
#then
students=pandas.DataFrame({key:pandas.Series(value) for key, value in classroom.items()})

# seeing it:
students
# Out:
#      student   age     edu   country
# 0       Qing  32.0    Bach  PR China
# 1  Françoise  33.0    Bach   Senegal
# 2       Raúl  28.0  Master     Spain
# 3      Bjork  30.0     PhD    Norway
# 4      Marie   NaN     NaN       NaN

# %% [markdown]
# Sometimes, Python users code like this:

# %%
import pandas as pd # renaming the library

students=pd.DataFrame({key:pd.Series(value) for key, value in classroom.items()})
students
# Out:
#      student   age     edu   country
# 0       Qing  32.0    Bach  PR China
# 1  Françoise  33.0    Bach   Senegal
# 2       Raúl  28.0  Master     Spain
# 3      Bjork  30.0     PhD    Norway
# 4      Marie   NaN     NaN       NaN

# %% [markdown]
# ### Data frame basic operations

# %%
# data of structure: list? tuple? dataframe?
type(students)
# Out:
# pandas.core.frame.DataFrame

# %%
# type of data in data frame column
students.dtypes
# Out:
# student     object
# age        float64
# edu         object
# country     object
# dtype: object

# %%
# details of data frame
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5 entries, 0 to 4
# Data columns (total 4 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   student  5 non-null      object
#  1   age      4 non-null      float64
#  2   edu      4 non-null      object
#  3   country  4 non-null      object
# dtypes: float64(1), object(3)
# memory usage: 288.0+ bytes

# %%
# number of rows and columns
students.shape
# Out:
# (5, 4)

# %%
# number of rows:
len(students)
# Out:
# 5

# %%
# first rows
students.head(2) # compare with: students.tail(2)
# Out:
#      student   age   edu   country
# 0       Qing  32.0  Bach  PR China
# 1  Françoise  33.0  Bach   Senegal

# %%
# name of columns
students.columns
# Out:
# Index(['student', 'age', 'edu', 'country'], dtype='object')

# %% [markdown]
# If you needed the column names as a list:

# %%
students.columns.tolist()# or simply: list(students)
# Out:
# ['student', 'age', 'edu', 'country']

# %% [markdown]
# If you needed a column values as a list:

# %%
students.age.tolist()# list(students.ages)
# Out:
# [32.0, 33.0, 28.0, 30.0, nan]

# %% [markdown]
# ### Accesing elements in DF:
#
# The data frames in pandas behave much like in R:

# %%
#one particular column
students.student
# Out:
# 0         Qing
# 1    Françoise
# 2         Raúl
# 3        Bjork
# 4        Marie
# Name: student, dtype: object

# %%
# or
students['student']
# Out:
# 0         Qing
# 1    Françoise
# 2         Raúl
# 3        Bjork
# 4        Marie
# Name: student, dtype: object

# %%
# it is not the same as: 
students[['student']] # a data frame, not a column (or series)
# Out:
#      student
# 0       Qing
# 1  Françoise
# 2       Raúl
# 3      Bjork
# 4      Marie

# %%
# this is also a DF
students[['country','student']]
# Out:
#     country    student
# 0  PR China       Qing
# 1   Senegal  Françoise
# 2     Spain       Raúl
# 3    Norway      Bjork
# 4       NaN      Marie

# %%
# and this, using loc:
columnNames=['country','student']
students.loc[:,columnNames]
# Out:
#     country    student
# 0  PR China       Qing
# 1   Senegal  Françoise
# 2     Spain       Raúl
# 3    Norway      Bjork
# 4       NaN      Marie

# %%
## Using positions is very common:
columnPositions=[1,3,0]
students.iloc[:,columnPositions]
# Out:
#     age   country    student
# 0  32.0  PR China       Qing
# 1  33.0   Senegal  Françoise
# 2  28.0     Spain       Raúl
# 3  30.0    Norway      Bjork
# 4   NaN       NaN      Marie

# %% [markdown]
# ### Changing values
#
# If you have a position, you can update values:

# %%
students.iloc[4,1]=23 # change is immediate! (no warning)
students
# Out:
#      student   age     edu   country
# 0       Qing  32.0    Bach  PR China
# 1  Françoise  33.0    Bach   Senegal
# 2       Raúl  28.0  Master     Spain
# 3      Bjork  30.0     PhD    Norway
# 4      Marie  23.0     NaN       NaN

# %% [markdown]
# ### Deleting columns

# %% [markdown]
# You can modify any values in a data frame, but let me create a **deep** copy of this data frame to play with:

# %%
studentsCopy=students.copy()
studentsCopy
# Out:
#      student   age     edu   country
# 0       Qing  32.0    Bach  PR China
# 1  Françoise  33.0    Bach   Senegal
# 2       Raúl  28.0  Master     Spain
# 3      Bjork  30.0     PhD    Norway
# 4      Marie  23.0     NaN       NaN

# %%
# This is what you want get rid of:
byeColumns=['edu'] # you can delete more than one

#this is the result
studentsCopy.drop(columns=byeColumns)
# Out:
#      student   age   country
# 0       Qing  32.0  PR China
# 1  Françoise  33.0   Senegal
# 2       Raúl  28.0     Spain
# 3      Bjork  30.0    Norway
# 4      Marie  23.0       NaN

# %% [markdown]
# Notice you do not have saved the previous result:

# %%
studentsCopy
# Out:
#      student   age     edu   country
# 0       Qing  32.0    Bach  PR China
# 1  Françoise  33.0    Bach   Senegal
# 2       Raúl  28.0  Master     Spain
# 3      Bjork  30.0     PhD    Norway
# 4      Marie  23.0     NaN       NaN

# %%
#NOW we do
studentsCopy.drop(columns=byeColumns,inplace=True)

# %%
#then:
studentsCopy
# Out:
#      student   age   country
# 0       Qing  32.0  PR China
# 1  Françoise  33.0   Senegal
# 2       Raúl  28.0     Spain
# 3      Bjork  30.0    Norway
# 4      Marie  23.0       NaN

# %% [markdown]
# ### Deleting a row
#
# Let me delete a row:

# %%
# axis 0 is delete by row
studentsCopy.drop(index=2,inplace=True) 
studentsCopy
# Out:
#      student   age   country
# 0       Qing  32.0  PR China
# 1  Françoise  33.0   Senegal
# 3      Bjork  30.0    Norway
# 4      Marie  23.0       NaN

# %% [markdown]
# As you see, the index dissapeared. Then, you should reset the indexes:

# %%
studentsCopy.reset_index(drop=True,inplace=True)
studentsCopy
# Out:
#      student   age   country
# 0       Qing  32.0  PR China
# 1  Françoise  33.0   Senegal
# 2      Bjork  30.0    Norway
# 3      Marie  23.0       NaN

# %% [markdown]
# [home](#home)
# _____
#
# <a id='part2'></a>
#
#
# ## 2.  Data Pre processing

# %% [markdown]
# <a id='beginning'></a>
#
# Preprocessing includes three stages:
#
# a. **Cleaning**: Cleaning requires that every cell has the right value, and that the dataframe has only the contents needed. Having a clean data frame means:
#
#     1. Verify that headers are at the top of data frame, and well written.
#
#     2. Verify that categories levels are well written.
#
# <br>
#
# b. **Formatting**: Formatting requires:
#
#     1. Verifiying data types
#
#     2. Correcting data types: Numerical, categorical, text, date.
#
# <br>
#
# c. **Integrating and Saving**: It is process of combining several dataframes in one, and saving it into a file that can be the input of future processes.

# %% [markdown]
# _____
#
# <a id='cleanformat'></a>
#
# ## a. CLEANING

# %% [markdown]
# Let's start by bringing in a table from wikipedia:

# %%
LINK_to_WIKIPAGE="https://en.wikipedia.org/wiki/Democracy_Index"

democracy=pd.read_html(LINK_to_WIKIPAGE)

# %% [markdown]
# Democracy is not a data frame:

# %%
type(democracy)
# Out:
# list

# %% [markdown]
# This list has:

# %%
len(democracy)
# Out:
# 7

# %% [markdown]
# We could shorten the list of results by telling what kind of table you want:

# %%
democracy=pd.read_html(LINK_to_WIKIPAGE, attrs={"class":"wikitable sortable"})
len(democracy)
# Out:
# 2

# %% [markdown]
# Then, our table is:

# %%
democracy[0]
# Out:
#      Rank                           Country  Score  \
# 0       1                            Norway   9.87
# 1       2                           Iceland   9.58
# 2       3                            Sweden   9.39
# 3       4                       New Zealand   9.26
# 4       5                           Finland   9.25
# ..    ...                               ...    ...
# 163   164                             Syria   1.43
# 164   165          Central African Republic   1.32
# 165   166  Democratic Republic of the Congo   1.13
# 166   167                       North Korea   1.08
# 167  Rank                           Country  Score
#
#      Electoral processand pluralism  Functio­ning ofgovern­ment  \
# 0                             10.00                        9.64
# 1                             10.00                        9.29
# 2                              9.58                        9.64
# 3                             10.00                        9.29
# 4                             10.00                        8.93
# ..                              ...                         ...
# 163                            0.00                        0.00
# 164                            1.25                        0.00
# 165                            0.00                        0.00
# 166                            0.00                        2.50
# 167  Electoral processand pluralism  Functio­ning ofgovern­ment
#
#      Politicalpartici­pation  Politicalculture  Civilliberties  \
# 0                      10.00             10.00            9.71
# 1                       8.89             10.00            9.71
# 2                       8.33             10.00            9.41
# 3                       8.89              8.13           10.00
# 4                       8.89              8.75            9.71
# ..                       ...               ...             ...
# 163                     2.78              4.38            0.00
# 164                     1.11              1.88            2.35
# 165                     1.67              3.13            0.88
# 166                     1.67              1.25            0.00
# 167  Politicalpartici­pation  Politicalculture  Civilliberties
#
#          Regimetype                 Region[n 1]  Changes fromlast year
# 0    Full democracy              Western Europe           Score: Rank:
# 1    Full democracy              Western Europe           Score: Rank:
# 2    Full democracy              Western Europe           Score: Rank:
# 3    Full democracy          Asia & Australasia           Score: Rank:
# 4    Full democracy              Western Europe     Score: 0.11Rank: 3
# ..              ...                         ...                    ...
# 163   Authoritarian  Middle East & North Africa         Score: Rank: 2
# 164   Authoritarian          Sub-Saharan Africa      Score: 0.2Rank: 1
# 165   Authoritarian          Sub-Saharan Africa      Score: 0.2Rank: 1
# 166   Authoritarian          Asia & Australasia           Score: Rank:
# 167      Regimetype                      Region  Changes fromlast year
#
# [168 rows x 11 columns]

# %%
demodata=democracy[0]

# %% [markdown]
# 1. **Verify that headers are at the top of data frame, and well written**.

# %%
# headers are in the right position
# are they well written?
demodata.columns.to_list()
# Out:
# ['Rank',
#  'Country',
#  'Score',
#  'Electoral processand pluralism',
#  'Functio\xadning ofgovern\xadment',
#  'Politicalpartici\xadpation',
#  'Politicalculture',
#  'Civilliberties',
#  'Regimetype',
#  'Region[n 1]',
#  'Changes fromlast year']

# %%
old=demodata.columns.to_list()

# %%
import re

old_good=[re.split("\s",x)[0] for x in old]
old_good
# Out:
# ['Rank',
#  'Country',
#  'Score',
#  'Electoral',
#  'Functio\xadning',
#  'Politicalpartici\xadpation',
#  'Politicalculture',
#  'Civilliberties',
#  'Regimetype',
#  'Region[n',
#  'Changes']

# %%
old_better=[re.split("\[",x)[0] for x in old_good]
old_better
# Out:
# ['Rank',
#  'Country',
#  'Score',
#  'Electoral',
#  'Functio\xadning',
#  'Politicalpartici\xadpation',
#  'Politicalculture',
#  'Civilliberties',
#  'Regimetype',
#  'Region',
#  'Changes']

# %%
old_better=[re.split("\s|\[",x)[0] for x in old]
old_better
# Out:
# ['Rank',
#  'Country',
#  'Score',
#  'Electoral',
#  'Functio\xadning',
#  'Politicalpartici\xadpation',
#  'Politicalculture',
#  'Civilliberties',
#  'Regimetype',
#  'Region',
#  'Changes']

# %%
allOK=[re.sub(r'\W+', '', x) for x in old_better]
allOK
# Out:
# ['Rank',
#  'Country',
#  'Score',
#  'Electoral',
#  'Functioning',
#  'Politicalparticipation',
#  'Politicalculture',
#  'Civilliberties',
#  'Regimetype',
#  'Region',
#  'Changes']

# %%
allOK[2:]
# Out:
# ['Score',
#  'Electoral',
#  'Functioning',
#  'Politicalparticipation',
#  'Politicalculture',
#  'Civilliberties',
#  'Regimetype',
#  'Region',
#  'Changes']

# %%
demodata.columns[2:]
# Out:
# Index(['Score', 'Electoral processand pluralism', 'Functio­ning ofgovern­ment',
#        'Politicalpartici­pation', 'Politicalculture', 'Civilliberties',
#        'Regimetype', 'Region[n 1]', 'Changes fromlast year'],
#       dtype='object')

# %%
dict(zip(demodata.columns[2:],allOK[2:]))
# Out:
# {'Score': 'Score',
#  'Electoral processand pluralism': 'Electoral',
#  'Functio\xadning ofgovern\xadment': 'Functioning',
#  'Politicalpartici\xadpation': 'Politicalparticipation',
#  'Politicalculture': 'Politicalculture',
#  'Civilliberties': 'Civilliberties',
#  'Regimetype': 'Regimetype',
#  'Region[n 1]': 'Region',
#  'Changes fromlast year': 'Changes'}

# %%
changes=dict(zip(demodata.columns[2:],allOK[2:]))
demodata.rename(columns=changes)
# Out:
#      Rank                           Country  Score  \
# 0       1                            Norway   9.87
# 1       2                           Iceland   9.58
# 2       3                            Sweden   9.39
# 3       4                       New Zealand   9.26
# 4       5                           Finland   9.25
# ..    ...                               ...    ...
# 163   164                             Syria   1.43
# 164   165          Central African Republic   1.32
# 165   166  Democratic Republic of the Congo   1.13
# 166   167                       North Korea   1.08
# 167  Rank                           Country  Score
#
#                           Electoral                 Functioning  \
# 0                             10.00                        9.64
# 1                             10.00                        9.29
# 2                              9.58                        9.64
# 3                             10.00                        9.29
# 4                             10.00                        8.93
# ..                              ...                         ...
# 163                            0.00                        0.00
# 164                            1.25                        0.00
# 165                            0.00                        0.00
# 166                            0.00                        2.50
# 167  Electoral processand pluralism  Functio­ning ofgovern­ment
#
#       Politicalparticipation  Politicalculture  Civilliberties  \
# 0                      10.00             10.00            9.71
# 1                       8.89             10.00            9.71
# 2                       8.33             10.00            9.41
# 3                       8.89              8.13           10.00
# 4                       8.89              8.75            9.71
# ..                       ...               ...             ...
# 163                     2.78              4.38            0.00
# 164                     1.11              1.88            2.35
# 165                     1.67              3.13            0.88
# 166                     1.67              1.25            0.00
# 167  Politicalpartici­pation  Politicalculture  Civilliberties
#
#          Regimetype                      Region                Changes
# 0    Full democracy              Western Europe           Score: Rank:
# 1    Full democracy              Western Europe           Score: Rank:
# 2    Full democracy              Western Europe           Score: Rank:
# 3    Full democracy          Asia & Australasia           Score: Rank:
# 4    Full democracy              Western Europe     Score: 0.11Rank: 3
# ..              ...                         ...                    ...
# 163   Authoritarian  Middle East & North Africa         Score: Rank: 2
# 164   Authoritarian          Sub-Saharan Africa      Score: 0.2Rank: 1
# 165   Authoritarian          Sub-Saharan Africa      Score: 0.2Rank: 1
# 166   Authoritarian          Asia & Australasia           Score: Rank:
# 167      Regimetype                      Region  Changes fromlast year
#
# [168 rows x 11 columns]

# %%
demodata
# Out:
#      Rank                           Country  Score  \
# 0       1                            Norway   9.87
# 1       2                           Iceland   9.58
# 2       3                            Sweden   9.39
# 3       4                       New Zealand   9.26
# 4       5                           Finland   9.25
# ..    ...                               ...    ...
# 163   164                             Syria   1.43
# 164   165          Central African Republic   1.32
# 165   166  Democratic Republic of the Congo   1.13
# 166   167                       North Korea   1.08
# 167  Rank                           Country  Score
#
#      Electoral processand pluralism  Functio­ning ofgovern­ment  \
# 0                             10.00                        9.64
# 1                             10.00                        9.29
# 2                              9.58                        9.64
# 3                             10.00                        9.29
# 4                             10.00                        8.93
# ..                              ...                         ...
# 163                            0.00                        0.00
# 164                            1.25                        0.00
# 165                            0.00                        0.00
# 166                            0.00                        2.50
# 167  Electoral processand pluralism  Functio­ning ofgovern­ment
#
#      Politicalpartici­pation  Politicalculture  Civilliberties  \
# 0                      10.00             10.00            9.71
# 1                       8.89             10.00            9.71
# 2                       8.33             10.00            9.41
# 3                       8.89              8.13           10.00
# 4                       8.89              8.75            9.71
# ..                       ...               ...             ...
# 163                     2.78              4.38            0.00
# 164                     1.11              1.88            2.35
# 165                     1.67              3.13            0.88
# 166                     1.67              1.25            0.00
# 167  Politicalpartici­pation  Politicalculture  Civilliberties
#
#          Regimetype                 Region[n 1]  Changes fromlast year
# 0    Full democracy              Western Europe           Score: Rank:
# 1    Full democracy              Western Europe           Score: Rank:
# 2    Full democracy              Western Europe           Score: Rank:
# 3    Full democracy          Asia & Australasia           Score: Rank:
# 4    Full democracy              Western Europe     Score: 0.11Rank: 3
# ..              ...                         ...                    ...
# 163   Authoritarian  Middle East & North Africa         Score: Rank: 2
# 164   Authoritarian          Sub-Saharan Africa      Score: 0.2Rank: 1
# 165   Authoritarian          Sub-Saharan Africa      Score: 0.2Rank: 1
# 166   Authoritarian          Asia & Australasia           Score: Rank:
# 167      Regimetype                      Region  Changes fromlast year
#
# [168 rows x 11 columns]

# %%
demodata.rename(columns=changes,inplace=True)

# %%
demodata
# Out:
#      Rank                           Country  Score  \
# 0       1                            Norway   9.87
# 1       2                           Iceland   9.58
# 2       3                            Sweden   9.39
# 3       4                       New Zealand   9.26
# 4       5                           Finland   9.25
# ..    ...                               ...    ...
# 163   164                             Syria   1.43
# 164   165          Central African Republic   1.32
# 165   166  Democratic Republic of the Congo   1.13
# 166   167                       North Korea   1.08
# 167  Rank                           Country  Score
#
#                           Electoral                 Functioning  \
# 0                             10.00                        9.64
# 1                             10.00                        9.29
# 2                              9.58                        9.64
# 3                             10.00                        9.29
# 4                             10.00                        8.93
# ..                              ...                         ...
# 163                            0.00                        0.00
# 164                            1.25                        0.00
# 165                            0.00                        0.00
# 166                            0.00                        2.50
# 167  Electoral processand pluralism  Functio­ning ofgovern­ment
#
#       Politicalparticipation  Politicalculture  Civilliberties  \
# 0                      10.00             10.00            9.71
# 1                       8.89             10.00            9.71
# 2                       8.33             10.00            9.41
# 3                       8.89              8.13           10.00
# 4                       8.89              8.75            9.71
# ..                       ...               ...             ...
# 163                     2.78              4.38            0.00
# 164                     1.11              1.88            2.35
# 165                     1.67              3.13            0.88
# 166                     1.67              1.25            0.00
# 167  Politicalpartici­pation  Politicalculture  Civilliberties
#
#          Regimetype                      Region                Changes
# 0    Full democracy              Western Europe           Score: Rank:
# 1    Full democracy              Western Europe           Score: Rank:
# 2    Full democracy              Western Europe           Score: Rank:
# 3    Full democracy          Asia & Australasia           Score: Rank:
# 4    Full democracy              Western Europe     Score: 0.11Rank: 3
# ..              ...                         ...                    ...
# 163   Authoritarian  Middle East & North Africa         Score: Rank: 2
# 164   Authoritarian          Sub-Saharan Africa      Score: 0.2Rank: 1
# 165   Authoritarian          Sub-Saharan Africa      Score: 0.2Rank: 1
# 166   Authoritarian          Asia & Australasia           Score: Rank:
# 167      Regimetype                      Region  Changes fromlast year
#
# [168 rows x 11 columns]

# %% [markdown]
# 2. **Verify that categories levels are well written**.
#
# This requires getting frequency tables:

# %%
demodata.Regimetype.value_counts()
# Out:
# Flawed democracy    54
# Authoritarian       54
# Hybrid regime       37
# Full democracy      22
# Regimetype           1
# Name: Regimetype, dtype: int64

# %% [markdown]
# You just identified a weird level **Regimetype**, that might signal a **wrong row**:

# %%
demodata[demodata.Regimetype=="Regimetype"]
# Out:
#      Rank  Country  Score                       Electoral  \
# 167  Rank  Country  Score  Electoral processand pluralism
#
#                     Functioning   Politicalparticipation  Politicalculture  \
# 167  Functio­ning ofgovern­ment  Politicalpartici­pation  Politicalculture
#
#      Civilliberties  Regimetype  Region                Changes
# 167  Civilliberties  Regimetype  Region  Changes fromlast year

# %% [markdown]
# You found a row that did not follow the pattern of the rest. The last step before formatting will be to remove these rows and the columns you do not need.

# %%
# strategy 1: subsetting
demodataRowsOK=demodata[demodata.Regimetype!="Regimetype"]
demodataRowsOK
# Out:
#     Rank                           Country Score Electoral Functioning  \
# 0      1                            Norway  9.87     10.00        9.64
# 1      2                           Iceland  9.58     10.00        9.29
# 2      3                            Sweden  9.39      9.58        9.64
# 3      4                       New Zealand  9.26     10.00        9.29
# 4      5                           Finland  9.25     10.00        8.93
# ..   ...                               ...   ...       ...         ...
# 162  163                              Chad  1.61      0.00        0.00
# 163  164                             Syria  1.43      0.00        0.00
# 164  165          Central African Republic  1.32      1.25        0.00
# 165  166  Democratic Republic of the Congo  1.13      0.00        0.00
# 166  167                       North Korea  1.08      0.00        2.50
#
#     Politicalparticipation Politicalculture Civilliberties      Regimetype  \
# 0                    10.00            10.00           9.71  Full democracy
# 1                     8.89            10.00           9.71  Full democracy
# 2                     8.33            10.00           9.41  Full democracy
# 3                     8.89             8.13          10.00  Full democracy
# 4                     8.89             8.75           9.71  Full democracy
# ..                     ...              ...            ...             ...
# 162                   1.67             3.75           2.65   Authoritarian
# 163                   2.78             4.38           0.00   Authoritarian
# 164                   1.11             1.88           2.35   Authoritarian
# 165                   1.67             3.13           0.88   Authoritarian
# 166                   1.67             1.25           0.00   Authoritarian
#
#                          Region             Changes
# 0                Western Europe        Score: Rank:
# 1                Western Europe        Score: Rank:
# 2                Western Europe        Score: Rank:
# 3            Asia & Australasia        Score: Rank:
# 4                Western Europe  Score: 0.11Rank: 3
# ..                          ...                 ...
# 162          Sub-Saharan Africa        Score: Rank:
# 163  Middle East & North Africa      Score: Rank: 2
# 164          Sub-Saharan Africa   Score: 0.2Rank: 1
# 165          Sub-Saharan Africa   Score: 0.2Rank: 1
# 166          Asia & Australasia        Score: Rank:
#
# [167 rows x 11 columns]

# %%
# strategy 2: droping by index
demodata.drop(index=167)
# Out:
#     Rank                           Country Score Electoral Functioning  \
# 0      1                            Norway  9.87     10.00        9.64
# 1      2                           Iceland  9.58     10.00        9.29
# 2      3                            Sweden  9.39      9.58        9.64
# 3      4                       New Zealand  9.26     10.00        9.29
# 4      5                           Finland  9.25     10.00        8.93
# ..   ...                               ...   ...       ...         ...
# 162  163                              Chad  1.61      0.00        0.00
# 163  164                             Syria  1.43      0.00        0.00
# 164  165          Central African Republic  1.32      1.25        0.00
# 165  166  Democratic Republic of the Congo  1.13      0.00        0.00
# 166  167                       North Korea  1.08      0.00        2.50
#
#     Politicalparticipation Politicalculture Civilliberties      Regimetype  \
# 0                    10.00            10.00           9.71  Full democracy
# 1                     8.89            10.00           9.71  Full democracy
# 2                     8.33            10.00           9.41  Full democracy
# 3                     8.89             8.13          10.00  Full democracy
# 4                     8.89             8.75           9.71  Full democracy
# ..                     ...              ...            ...             ...
# 162                   1.67             3.75           2.65   Authoritarian
# 163                   2.78             4.38           0.00   Authoritarian
# 164                   1.11             1.88           2.35   Authoritarian
# 165                   1.67             3.13           0.88   Authoritarian
# 166                   1.67             1.25           0.00   Authoritarian
#
#                          Region             Changes
# 0                Western Europe        Score: Rank:
# 1                Western Europe        Score: Rank:
# 2                Western Europe        Score: Rank:
# 3            Asia & Australasia        Score: Rank:
# 4                Western Europe  Score: 0.11Rank: 3
# ..                          ...                 ...
# 162          Sub-Saharan Africa        Score: Rank:
# 163  Middle East & North Africa      Score: Rank: 2
# 164          Sub-Saharan Africa   Score: 0.2Rank: 1
# 165          Sub-Saharan Africa   Score: 0.2Rank: 1
# 166          Asia & Australasia        Score: Rank:
#
# [167 rows x 11 columns]

# %% [markdown]
# Let's keep strategy 1, get rid of the unneeded columns:

# %%
[1]+ list(range(3,9) )
# Out:
# [1, 3, 4, 5, 6, 7, 8]

# %%
# strategy 1: subsetting
keepPositions=[1]+ list(range(3,9) )
demodataRowsOK.iloc[:,keepPositions]
# Out:
#                               Country Electoral Functioning  \
# 0                              Norway     10.00        9.64
# 1                             Iceland     10.00        9.29
# 2                              Sweden      9.58        9.64
# 3                         New Zealand     10.00        9.29
# 4                             Finland     10.00        8.93
# ..                                ...       ...         ...
# 162                              Chad      0.00        0.00
# 163                             Syria      0.00        0.00
# 164          Central African Republic      1.25        0.00
# 165  Democratic Republic of the Congo      0.00        0.00
# 166                       North Korea      0.00        2.50
#
#     Politicalparticipation Politicalculture Civilliberties      Regimetype
# 0                    10.00            10.00           9.71  Full democracy
# 1                     8.89            10.00           9.71  Full democracy
# 2                     8.33            10.00           9.41  Full democracy
# 3                     8.89             8.13          10.00  Full democracy
# 4                     8.89             8.75           9.71  Full democracy
# ..                     ...              ...            ...             ...
# 162                   1.67             3.75           2.65   Authoritarian
# 163                   2.78             4.38           0.00   Authoritarian
# 164                   1.11             1.88           2.35   Authoritarian
# 165                   1.67             3.13           0.88   Authoritarian
# 166                   1.67             1.25           0.00   Authoritarian
#
# [167 rows x 7 columns]

# %%
# strategy 2: dropping
bye=['Rank','Score','Changes']
demodataRowsOK.drop(columns=bye)
# Out:
#                               Country Electoral Functioning  \
# 0                              Norway     10.00        9.64
# 1                             Iceland     10.00        9.29
# 2                              Sweden      9.58        9.64
# 3                         New Zealand     10.00        9.29
# 4                             Finland     10.00        8.93
# ..                                ...       ...         ...
# 162                              Chad      0.00        0.00
# 163                             Syria      0.00        0.00
# 164          Central African Republic      1.25        0.00
# 165  Democratic Republic of the Congo      0.00        0.00
# 166                       North Korea      0.00        2.50
#
#     Politicalparticipation Politicalculture Civilliberties      Regimetype  \
# 0                    10.00            10.00           9.71  Full democracy
# 1                     8.89            10.00           9.71  Full democracy
# 2                     8.33            10.00           9.41  Full democracy
# 3                     8.89             8.13          10.00  Full democracy
# 4                     8.89             8.75           9.71  Full democracy
# ..                     ...              ...            ...             ...
# 162                   1.67             3.75           2.65   Authoritarian
# 163                   2.78             4.38           0.00   Authoritarian
# 164                   1.11             1.88           2.35   Authoritarian
# 165                   1.67             3.13           0.88   Authoritarian
# 166                   1.67             1.25           0.00   Authoritarian
#
#                          Region
# 0                Western Europe
# 1                Western Europe
# 2                Western Europe
# 3            Asia & Australasia
# 4                Western Europe
# ..                          ...
# 162          Sub-Saharan Africa
# 163  Middle East & North Africa
# 164          Sub-Saharan Africa
# 165          Sub-Saharan Africa
# 166          Asia & Australasia
#
# [167 rows x 8 columns]

# %% [markdown]
# Let's use strategy 2 this time:

# %%
demodataok=demodataRowsOK.drop(columns=bye)
demodataok
# Out:
#                               Country Electoral Functioning  \
# 0                              Norway     10.00        9.64
# 1                             Iceland     10.00        9.29
# 2                              Sweden      9.58        9.64
# 3                         New Zealand     10.00        9.29
# 4                             Finland     10.00        8.93
# ..                                ...       ...         ...
# 162                              Chad      0.00        0.00
# 163                             Syria      0.00        0.00
# 164          Central African Republic      1.25        0.00
# 165  Democratic Republic of the Congo      0.00        0.00
# 166                       North Korea      0.00        2.50
#
#     Politicalparticipation Politicalculture Civilliberties      Regimetype  \
# 0                    10.00            10.00           9.71  Full democracy
# 1                     8.89            10.00           9.71  Full democracy
# 2                     8.33            10.00           9.41  Full democracy
# 3                     8.89             8.13          10.00  Full democracy
# 4                     8.89             8.75           9.71  Full democracy
# ..                     ...              ...            ...             ...
# 162                   1.67             3.75           2.65   Authoritarian
# 163                   2.78             4.38           0.00   Authoritarian
# 164                   1.11             1.88           2.35   Authoritarian
# 165                   1.67             3.13           0.88   Authoritarian
# 166                   1.67             1.25           0.00   Authoritarian
#
#                          Region
# 0                Western Europe
# 1                Western Europe
# 2                Western Europe
# 3            Asia & Australasia
# 4                Western Europe
# ..                          ...
# 162          Sub-Saharan Africa
# 163  Middle East & North Africa
# 164          Sub-Saharan Africa
# 165          Sub-Saharan Africa
# 166          Asia & Australasia
#
# [167 rows x 8 columns]

# %% [markdown]
# ## b. FORMATTING
#
# 1. Verifiying data types

# %%
demodataok.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 167 entries, 0 to 166
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 167 non-null    object
#  1   Electoral               167 non-null    object
#  2   Functioning             167 non-null    object
#  3   Politicalparticipation  167 non-null    object
#  4   Politicalculture        167 non-null    object
#  5   Civilliberties          167 non-null    object
#  6   Regimetype              167 non-null    object
#  7   Region                  167 non-null    object
# dtypes: object(8)
# memory usage: 11.7+ KB

# %% [markdown]
# The columns **Country** is text, then it is OK this is **object** data type.
# The Column **Regimetype** is ordinal,  **Region** is nominal, and the rest are **numerical**: we need to make those changes.
#
# Let's start with **Regimetype**:

# %%
demodataok.Regimetype.value_counts()
# Out:
# Flawed democracy    54
# Authoritarian       54
# Hybrid regime       37
# Full democracy      22
# Name: Regimetype, dtype: int64

# %%
from pandas.api.types import CategoricalDtype

# create data type
levelsRegime=CategoricalDtype(categories=["Authoritarian","Hybrid regime","Flawed democracy","Full democracy"],ordered=True)
# make the change:
demodataok.Regimetype=demodataok.Regimetype.astype(levelsRegime)

# %% [markdown]
# See the difference:

# %%
demodataok.Regimetype
# Out:
# 0      Full democracy
# 1      Full democracy
# 2      Full democracy
# 3      Full democracy
# 4      Full democracy
#             ...
# 162     Authoritarian
# 163     Authoritarian
# 164     Authoritarian
# 165     Authoritarian
# 166     Authoritarian
# Name: Regimetype, Length: 167, dtype: category
# Categories (4, object): ['Authoritarian' < 'Hybrid regime' < 'Flawed democracy' < 'Full democracy']

# %% [markdown]
# Now **Region**:

# %%
demodataok.Region.value_counts()
# Out:
# Sub-Saharan Africa            44
# Eastern Europe                28
# Asia & Australasia            28
# Latin America                 24
# Western Europe                21
# Middle East & North Africa    20
# North America                  2
# Name: Region, dtype: int64

# %%
demodataok.Region=demodataok.Region.astype('category')

# %%
demodataok.Region
# Out:
# 0                  Western Europe
# 1                  Western Europe
# 2                  Western Europe
# 3              Asia & Australasia
# 4                  Western Europe
#                   ...
# 162            Sub-Saharan Africa
# 163    Middle East & North Africa
# 164            Sub-Saharan Africa
# 165            Sub-Saharan Africa
# 166            Asia & Australasia
# Name: Region, Length: 167, dtype: category
# Categories (7, object): ['Asia & Australasia', 'Eastern Europe', 'Latin America', 'Middle East & North Africa', 'North America', 'Sub-Saharan Africa', 'Western Europe']

# %% [markdown]
# Now the numerical data:

# %%
demodataok.iloc[:,1:6]
# Out:
#     Electoral Functioning Politicalparticipation Politicalculture  \
# 0       10.00        9.64                  10.00            10.00
# 1       10.00        9.29                   8.89            10.00
# 2        9.58        9.64                   8.33            10.00
# 3       10.00        9.29                   8.89             8.13
# 4       10.00        8.93                   8.89             8.75
# ..        ...         ...                    ...              ...
# 162      0.00        0.00                   1.67             3.75
# 163      0.00        0.00                   2.78             4.38
# 164      1.25        0.00                   1.11             1.88
# 165      0.00        0.00                   1.67             3.13
# 166      0.00        2.50                   1.67             1.25
#
#     Civilliberties
# 0             9.71
# 1             9.71
# 2             9.41
# 3            10.00
# 4             9.71
# ..             ...
# 162           2.65
# 163           0.00
# 164           2.35
# 165           0.88
# 166           0.00
#
# [167 rows x 5 columns]

# %%
demodataok.iloc[:,1:6].astype('float')
# Out:
#      Electoral  Functioning  Politicalparticipation  Politicalculture  \
# 0        10.00         9.64                   10.00             10.00
# 1        10.00         9.29                    8.89             10.00
# 2         9.58         9.64                    8.33             10.00
# 3        10.00         9.29                    8.89              8.13
# 4        10.00         8.93                    8.89              8.75
# ..         ...          ...                     ...               ...
# 162       0.00         0.00                    1.67              3.75
# 163       0.00         0.00                    2.78              4.38
# 164       1.25         0.00                    1.11              1.88
# 165       0.00         0.00                    1.67              3.13
# 166       0.00         2.50                    1.67              1.25
#
#      Civilliberties
# 0              9.71
# 1              9.71
# 2              9.41
# 3             10.00
# 4              9.71
# ..              ...
# 162            2.65
# 163            0.00
# 164            2.35
# 165            0.88
# 166            0.00
#
# [167 rows x 5 columns]

# %% [markdown]
# 2. Correcting data types: Numerical, categorical, text, date.

# %%
demodataok.iloc[:,1:6].apply(pd.to_numeric, errors='coerce')
# Out:
#      Electoral  Functioning  Politicalparticipation  Politicalculture  \
# 0        10.00         9.64                   10.00             10.00
# 1        10.00         9.29                    8.89             10.00
# 2         9.58         9.64                    8.33             10.00
# 3        10.00         9.29                    8.89              8.13
# 4        10.00         8.93                    8.89              8.75
# ..         ...          ...                     ...               ...
# 162       0.00         0.00                    1.67              3.75
# 163       0.00         0.00                    2.78              4.38
# 164       1.25         0.00                    1.11              1.88
# 165       0.00         0.00                    1.67              3.13
# 166       0.00         2.50                    1.67              1.25
#
#      Civilliberties
# 0              9.71
# 1              9.71
# 2              9.41
# 3             10.00
# 4              9.71
# ..              ...
# 162            2.65
# 163            0.00
# 164            2.35
# 165            0.88
# 166            0.00
#
# [167 rows x 5 columns]

# %%
namesToNumeric=demodataok.iloc[:,1:6].columns
namesToNumeric
# Out:
# Index(['Electoral', 'Functioning', 'Politicalparticipation',
#        'Politicalculture', 'Civilliberties'],
#       dtype='object')

# %%
demodataok[namesToNumeric]=demodataok.iloc[:,1:6].apply(pd.to_numeric, errors='coerce')

# %%
demodataok.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 167 entries, 0 to 166
# Data columns (total 8 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Country                 167 non-null    object
#  1   Electoral               167 non-null    float64
#  2   Functioning             167 non-null    float64
#  3   Politicalparticipation  167 non-null    float64
#  4   Politicalculture        167 non-null    float64
#  5   Civilliberties          167 non-null    float64
#  6   Regimetype              167 non-null    category
#  7   Region                  167 non-null    category
# dtypes: category(2), float64(5), object(1)
# memory usage: 10.0+ KB

# %% [markdown]
# [home](#home)
#
# ______
#
# <a id='integratesave'></a>
#
# ## INTEGRATING AND SAVING

# %%
codes=pd.read_csv("countryCodes.csv")
codes
# Out:
#     FIPS ISO2 ISO3                                  NAME
# 0     AC   AG  ATG                   Antigua and Barbuda
# 1     AG   DZ  DZA                               Algeria
# 2     AJ   AZ  AZE                            Azerbaijan
# 3     AL   AL  ALB                               Albania
# 4     AM   AM  ARM                               Armenia
# ..   ...  ...  ...                                   ...
# 241   TB   BL  BLM                      Saint Barthelemy
# 242   GK   GG  GGY                              Guernsey
# 243   JE   JE  JEY                                Jersey
# 244   SX   GS  SGS  South Georgia South Sandwich Islands
# 245   TW   TW  TWN                                Taiwan
#
# [246 rows x 4 columns]

# %%
demomerged=demodataok.merge(codes,left_on='Country', right_on="NAME",how='outer',indicator=True)
demomerged
# Out:
#          Country  Electoral  Functioning  Politicalparticipation  \
# 0         Norway      10.00         9.64                   10.00
# 1        Iceland      10.00         9.29                    8.89
# 2         Sweden       9.58         9.64                    8.33
# 3    New Zealand      10.00         9.29                    8.89
# 4        Finland      10.00         8.93                    8.89
# ..           ...        ...          ...                     ...
# 255          NaN        NaN          NaN                     NaN
# 256          NaN        NaN          NaN                     NaN
# 257          NaN        NaN          NaN                     NaN
# 258          NaN        NaN          NaN                     NaN
# 259          NaN        NaN          NaN                     NaN
#
#      Politicalculture  Civilliberties      Regimetype              Region  \
# 0               10.00            9.71  Full democracy      Western Europe
# 1               10.00            9.71  Full democracy      Western Europe
# 2               10.00            9.41  Full democracy      Western Europe
# 3                8.13           10.00  Full democracy  Asia & Australasia
# 4                8.75            9.71  Full democracy      Western Europe
# ..                ...             ...             ...                 ...
# 255               NaN             NaN             NaN                 NaN
# 256               NaN             NaN             NaN                 NaN
# 257               NaN             NaN             NaN                 NaN
# 258               NaN             NaN             NaN                 NaN
# 259               NaN             NaN             NaN                 NaN
#
#     FIPS ISO2 ISO3                                  NAME      _merge
# 0     NO   NO  NOR                                Norway        both
# 1     IC   IS  ISL                               Iceland        both
# 2     SW   SE  SWE                                Sweden        both
# 3     NZ   NZ  NZL                           New Zealand        both
# 4     FI   FI  FIN                               Finland        both
# ..   ...  ...  ...                                   ...         ...
# 255   RN   MF  MAF                          Saint Martin  right_only
# 256   TB   BL  BLM                      Saint Barthelemy  right_only
# 257   GK   GG  GGY                              Guernsey  right_only
# 258   JE   JE  JEY                                Jersey  right_only
# 259   SX   GS  SGS  South Georgia South Sandwich Islands  right_only
#
# [260 rows x 13 columns]

# %% [markdown]
# Whay both had in common:

# %%
demomerged[demomerged._merge=='both']
# Out:
#                               Country  Electoral  Functioning  \
# 0                              Norway      10.00         9.64
# 1                             Iceland      10.00         9.29
# 2                              Sweden       9.58         9.64
# 3                         New Zealand      10.00         9.29
# 4                             Finland      10.00         8.93
# ..                                ...        ...          ...
# 160                 Equatorial Guinea       0.00         0.43
# 161                      Turkmenistan       0.00         0.79
# 162                              Chad       0.00         0.00
# 164          Central African Republic       1.25         0.00
# 165  Democratic Republic of the Congo       0.00         0.00
#
#      Politicalparticipation  Politicalculture  Civilliberties      Regimetype  \
# 0                     10.00             10.00            9.71  Full democracy
# 1                      8.89             10.00            9.71  Full democracy
# 2                      8.33             10.00            9.41  Full democracy
# 3                      8.89              8.13           10.00  Full democracy
# 4                      8.89              8.75            9.71  Full democracy
# ..                      ...               ...             ...             ...
# 160                    3.33              4.38            1.47   Authoritarian
# 161                    2.22              5.00            0.59   Authoritarian
# 162                    1.67              3.75            2.65   Authoritarian
# 164                    1.11              1.88            2.35   Authoritarian
# 165                    1.67              3.13            0.88   Authoritarian
#
#                  Region FIPS ISO2 ISO3                              NAME  \
# 0        Western Europe   NO   NO  NOR                            Norway
# 1        Western Europe   IC   IS  ISL                           Iceland
# 2        Western Europe   SW   SE  SWE                            Sweden
# 3    Asia & Australasia   NZ   NZ  NZL                       New Zealand
# 4        Western Europe   FI   FI  FIN                           Finland
# ..                  ...  ...  ...  ...                               ...
# 160  Sub-Saharan Africa   EK   GQ  GNQ                 Equatorial Guinea
# 161      Eastern Europe   TX   TM  TKM                      Turkmenistan
# 162  Sub-Saharan Africa   CD   TD  TCD                              Chad
# 164  Sub-Saharan Africa   CT   CF  CAF          Central African Republic
# 165  Sub-Saharan Africa   CG   CD  COD  Democratic Republic of the Congo
#
#     _merge
# 0     both
# 1     both
# 2     both
# 3     both
# 4     both
# ..     ...
# 160   both
# 161   both
# 162   both
# 164   both
# 165   both
#
# [153 rows x 13 columns]

# %% [markdown]
# What did not find a match:

# %%
demomerged[demomerged._merge=='left_only']
# Out:
#                    Country  Electoral  Functioning  Politicalparticipation  \
# 22        South Korea[n 2]       9.17         7.86                    7.22
# 76         North Macedonia       7.00         5.36                    6.67
# 82                 Moldova       6.58         4.64                    6.11
# 94                Tanzania       5.75         5.00                    5.00
# 110            Ivory Coast       4.33         2.86                    3.33
# 121                Myanmar       3.08         3.93                    2.78
# 131               Eswatini       0.92         2.86                    2.78
# 133  Republic of the Congo       2.17         2.50                    3.89
# 135                Vietnam       0.00         3.21                    3.89
# 150                   Iran       0.00         2.86                    4.44
# 154                   Laos       0.00         2.86                    1.67
# 155                  Libya       0.00         0.00                    2.78
# 163                  Syria       0.00         0.00                    2.78
# 166            North Korea       0.00         2.50                    1.67
#
#      Politicalculture  Civilliberties        Regimetype  \
# 22               7.50            8.24  Flawed democracy
# 76               3.75            7.06     Hybrid regime
# 82               4.38            7.06     Hybrid regime
# 94               5.63            4.41     Hybrid regime
# 110              5.63            4.12     Hybrid regime
# 121              5.63            2.35     Authoritarian
# 131              5.63            3.53     Authoritarian
# 133              3.75            3.24     Authoritarian
# 135              5.63            2.65     Authoritarian
# 150              3.13            1.47     Authoritarian
# 154              5.00            1.18     Authoritarian
# 155              4.38            2.94     Authoritarian
# 163              4.38            0.00     Authoritarian
# 166              1.25            0.00     Authoritarian
#
#                          Region FIPS ISO2 ISO3 NAME     _merge
# 22           Asia & Australasia  NaN  NaN  NaN  NaN  left_only
# 76               Eastern Europe  NaN  NaN  NaN  NaN  left_only
# 82               Eastern Europe  NaN  NaN  NaN  NaN  left_only
# 94           Sub-Saharan Africa  NaN  NaN  NaN  NaN  left_only
# 110          Sub-Saharan Africa  NaN  NaN  NaN  NaN  left_only
# 121          Asia & Australasia  NaN  NaN  NaN  NaN  left_only
# 131          Sub-Saharan Africa  NaN  NaN  NaN  NaN  left_only
# 133          Sub-Saharan Africa  NaN  NaN  NaN  NaN  left_only
# 135          Asia & Australasia  NaN  NaN  NaN  NaN  left_only
# 150  Middle East & North Africa  NaN  NaN  NaN  NaN  left_only
# 154          Asia & Australasia  NaN  NaN  NaN  NaN  left_only
# 155  Middle East & North Africa  NaN  NaN  NaN  NaN  left_only
# 163  Middle East & North Africa  NaN  NaN  NaN  NaN  left_only
# 166          Asia & Australasia  NaN  NaN  NaN  NaN  left_only

# %%
codes[codes.NAME.str.contains('Korea|Macedonia|Moldo|Tanza|Ivo|Burm|Swazi|Congo|Iran|Viet|Lao|Liby|Syr')]
# Out:
#     FIPS ISO2 ISO3                                       NAME
# 17    BM   MM  MMR                                      Burma
# 26    CF   CG  COG                                      Congo
# 27    CG   CD  COD           Democratic Republic of the Congo
# 83    IR   IR  IRN                 Iran (Islamic Republic of)
# 86    IV   CI  CIV                              Cote d'Ivoire
# 93    KN   KP  PRK     Korea, Democratic People's Republic of
# 95    KS   KR  KOR                         Korea, Republic of
# 98    LA   LA  LAO           Lao People's Democratic Republic
# 106   LY   LY  LBY                     Libyan Arab Jamahiriya
# 111   MK   MK  MKD  The former Yugoslav Republic of Macedonia
# 171   MD   MD  MDA                        Republic of Moldova
# 191   SY   SY  SYR                       Syrian Arab Republic
# 204   TZ   TZ  TZA                United Republic of Tanzania
# 215   VM   VN  VNM                                   Viet Nam
# 220   WZ   SZ  SWZ                                  Swaziland

# %%
currentNamesDemo=demomerged[demomerged._merge=='left_only'].Country.to_list()
currentNamesCodes=['Korea, Republic of','The former Yugoslav Republic of Macedonia','Republic of Moldova',
                  'United Republic of Tanzania',"Cote d'Ivoire",'Burma','Swaziland','Congo','Viet Nam',
                  'Iran (Islamic Republic of)',"Lao People's Democratic Republic",
                  'Libyan Arab Jamahiriya','Syrian Arab Republic',"Korea, Democratic People's Republic of"]

# %%
dict(zip(currentNamesDemo,currentNamesCodes))
# Out:
# {'South Korea[n 2]': 'Korea, Republic of',
#  'North Macedonia': 'The former Yugoslav Republic of Macedonia',
#  'Moldova': 'Republic of Moldova',
#  'Tanzania': 'United Republic of Tanzania',
#  'Ivory Coast': "Cote d'Ivoire",
#  'Myanmar': 'Burma',
#  'Eswatini': 'Swaziland',
#  'Republic of the Congo': 'Congo',
#  'Vietnam': 'Viet Nam',
#  'Iran': 'Iran (Islamic Republic of)',
#  'Laos': "Lao People's Democratic Republic",
#  'Libya': 'Libyan Arab Jamahiriya',
#  'Syria': 'Syrian Arab Republic',
#  'North Korea': "Korea, Democratic People's Republic of"}

# %%
###dictionary of replacements:
replacementsForDemo=dict(zip(currentNamesDemo,currentNamesCodes))

### replacing
demodataok.Country.replace(replacementsForDemo,inplace=True)

# %%
demomerged=demodataok.merge(codes,left_on='Country', right_on="NAME")
demomerged
# Out:
#                                     Country  Electoral  Functioning  \
# 0                                    Norway      10.00         9.64
# 1                                   Iceland      10.00         9.29
# 2                                    Sweden       9.58         9.64
# 3                               New Zealand      10.00         9.29
# 4                                   Finland      10.00         8.93
# ..                                      ...        ...          ...
# 162                                    Chad       0.00         0.00
# 163                    Syrian Arab Republic       0.00         0.00
# 164                Central African Republic       1.25         0.00
# 165        Democratic Republic of the Congo       0.00         0.00
# 166  Korea, Democratic People's Republic of       0.00         2.50
#
#      Politicalparticipation  Politicalculture  Civilliberties      Regimetype  \
# 0                     10.00             10.00            9.71  Full democracy
# 1                      8.89             10.00            9.71  Full democracy
# 2                      8.33             10.00            9.41  Full democracy
# 3                      8.89              8.13           10.00  Full democracy
# 4                      8.89              8.75            9.71  Full democracy
# ..                      ...               ...             ...             ...
# 162                    1.67              3.75            2.65   Authoritarian
# 163                    2.78              4.38            0.00   Authoritarian
# 164                    1.11              1.88            2.35   Authoritarian
# 165                    1.67              3.13            0.88   Authoritarian
# 166                    1.67              1.25            0.00   Authoritarian
#
#                          Region FIPS ISO2 ISO3  \
# 0                Western Europe   NO   NO  NOR
# 1                Western Europe   IC   IS  ISL
# 2                Western Europe   SW   SE  SWE
# 3            Asia & Australasia   NZ   NZ  NZL
# 4                Western Europe   FI   FI  FIN
# ..                          ...  ...  ...  ...
# 162          Sub-Saharan Africa   CD   TD  TCD
# 163  Middle East & North Africa   SY   SY  SYR
# 164          Sub-Saharan Africa   CT   CF  CAF
# 165          Sub-Saharan Africa   CG   CD  COD
# 166          Asia & Australasia   KN   KP  PRK
#
#                                        NAME
# 0                                    Norway
# 1                                   Iceland
# 2                                    Sweden
# 3                               New Zealand
# 4                                   Finland
# ..                                      ...
# 162                                    Chad
# 163                    Syrian Arab Republic
# 164                Central African Republic
# 165        Democratic Republic of the Congo
# 166  Korea, Democratic People's Republic of
#
# [167 rows x 12 columns]

# %%
demomerged.drop(columns="NAME",inplace=True)

# %%
demomerged.to_pickle("demomerged.pkl")
# you will need: DF=pd.read_pickle("demomerged.pkl")
# or:
# from urllib.request import urlopen
# DF=pd.read_pickle(urlopen("https://..../demomerged.pkl"),compression=None)

# %%
from rpy2.robjects import pandas2ri
pandas2ri.activate()

from rpy2.robjects.packages import importr

base = importr('base')
base.saveRDS(demomerged,file="demomerged.RDS")

#In R, you call it with: DF = readRDS("demomerged.RDS")
#or, if iyou read from cloud: DF = readRDS(url("https://..../demomerged.RDS")
# Out:
# /Users/JoseManuel/anaconda3/envs/Evans_GovAnalytics/lib/python3.7/site-packages/rpy2/robjects/vectors.py:980: UserWarning: R object inheriting from "POSIXct" but without attribute "tzone".
#   warnings.warn('R object inheriting from "POSIXct" but without '
# <rpy2.rinterface_lib.sexp.NULLType object at 0x7fdb51bb05a0> [RTYPES.NILSXP]
